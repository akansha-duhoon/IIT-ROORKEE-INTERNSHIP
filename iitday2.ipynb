# %%
#grade
a=int(input("enter marks:"))
if a>90:
    print("A")
elif a>75:
    print("B")
elif a>60:
    print("C")
else:
    print("F")
# Out:
# enter marks: 88
# B

# %%
a=int(input("enter the number:"))
for i in range(1,10):
     print("a*i=",a*i)
# Out:
# enter the number: 4
# a*i= 4
# a*i= 8
# a*i= 12
# a*i= 16
# a*i= 20
# a*i= 24
# a*i= 28
# a*i= 32
# a*i= 36

# %%
a=int(input("enter the number"))
while a<=50:
     print(a)
    a+=2
