# %%
  import sklearn
import numpy as np
import pandas as pd

print(f"Scikit-learn version: {sklearn.__version__}")
print("Environment setup successfully!")
# Out:
# Scikit-learn version: 1.6.1
# Environment setup successfully!

# %%
pip install scikit-learn matplotlib seaborn pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from sklearn.datasets import load_iris

# Load the dataset
iris = load_iris()

# Convert to a DataFrame for cleaner exploration
df = pd.DataFrame(data=iris.data, columns=iris.feature_names)
# Add the target (species) column
df['species'] = iris.target

# Map target integers to actual species names for readability
species_map = {0: 'setosa', 1: 'versicolor', 2: 'virginica'}
df['species_name'] = df['species'].map(species_map)

# --- 3a. Dataset Shape ---
print("--- Dataset Shape ---")
print(df.shape) 
# Output: (150, 6) -> 150 rows, 6 columns

# --- 3b. Dataset Description ---
print("\n--- Statistical Description ---")
print(df.describe())

# --- 3c. Value Counts (Class Distribution) ---
print("\n--- Species Value Counts ---")
print(df['species_name'].value_counts())
# Out:
# --- Dataset Shape ---
# (150, 6)
#
# --- Statistical Description ---
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)     species
# count        150.000000  150.000000
# mean           1.199333    1.000000
# std            0.762238    0.819232
# min            0.100000    0.000000
# 25%            0.300000    0.000000
# 50%            1.300000    1.000000
# 75%            1.800000    2.000000
# max            2.500000    2.000000
#
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set style for cleaner aesthetics
sns.set_theme(style="whitegrid")

# --- 4a. Histograms ---
# We will plot the distribution of the 4 physical features
features = iris.feature_names

plt.figure(figsize=(12, 8))
for i, col in enumerate(features, 1):
    plt.subplot(2, 2, i)
    sns.histplot(data=df, x=col, hue="species_name", kde=True, element="step", alpha=0.6)
    plt.title(f'Distribution of {col}')

plt.tight_layout()
plt.show()

# --- 4b. Pair Plots ---
# A pair plot maps every pairwise relationship across the features
sns.pairplot(df.drop(columns=['species']), hue="species_name", palette="Set2")
plt.suptitle("Pair Plot of Iris Features", y=1.02) # Adjusted title position
plt.show()
